# %%
import numpy as np
import pandas as pd
import json
import jpype
from bs4 import BeautifulSoup as bs

data_path = "data"
data_path = "data"

json_train=[]
for i in range(0,18):
    json_file = json.loads(open("%s/%d.json" % (data_path, i)).read())
    json_train += json_file["articles"]

# %%
import re
from konlpy.tag import Mecab

mecab = Mecab()

labeled_train = []

for cnt, article in enumerate(json_train):
    #text = bs(article["text"],"lxml").text
    text = article["text"]
    
    if cnt % 10000 == 0:
        print cnt

    labeled_train.append({
            "istroll": article["is_troll"],
            #"author": article["author"],
            #"author_morphs": mecab.morphs(article["author"]),
            #"forumid": article["forumid"],
            "lines": text.count('\n'),
            "spaces": text.count(' '),
            "tabs": text.count('\t'),
            "braces": text.count('{'),
            "brackets": text.count('['),
            "words": len(re.split('\s+', text)),
            "length": len(text)
        })

labeled_train = pd.DataFrame.from_dict(labeled_train)
labeled_train
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
#         braces  brackets istroll  length  lines  spaces  tabs  words
# 0            0         0   False      37      2       5     0      7
# 1            0         0   False     492      7      46     0     54
# 2            0         0   False      17      0       1     0      2
# 3            0         0   False      30      1       2     0      4
# 4            0         0   False      14      0       1     0      2
# 5            0         0   False      50      2       4     0      7
# 6            0         0   False     142      5      19     0     25
# 7            0         0   False      15      0       2     0      3
# 8            0         0   False     129      2      19     0     22
# 9            0         0   False      81      1       5     0      7
# 10           0         0   False      31      0       6     0      7
# 11           0         0   False      96      0       8     0      9
# 12           0         0   False      15      0       1     0      2
# 13           0         0   False     113      4      18     0     23
# 14           0         0   False      10      0       0     0      1
# 15           0         0   False      55      1       8     0     10
# 16           0         0   False     111      4      11     0     16
# 17           0         0   False      37      0       6     0      7
# 18           0         0   False       9      0       0     0      1
# 19           0         0   False      33      0       4     0      5
# 20           0         0   False      61      2       7     0     10
# 21           0         0   False      32      1       3     0      5
# 22           0         0   False    2838     15     125     0    141
# 23           0         0   False     289      5      20     0     26
# 24           0         0   False      14      0       1     0      2
# 25           0         0   False     106      0       3     0      4
# 26           0         0   False      15      0       1     0      2
# 27           0         0   False   26470     68    1565     0   1632
# 28           0         0   False      14      0       0     0      1
# 29           0         0   False     223      1      10     0     12
# ...        ...       ...     ...     ...    ...     ...   ...    ...
# 172014       0         0   False     345      0      71     0     76
# 172015       0         0    True      89      0      11     0     12
# 172016       0         0   False      51      0       3     0      4
# 172017       0         0   False     274      0      57     0     63
# 172018       0         0   False      49      0       9     0     11
# 172019       0         0   False      57      0      10     0     13
# 172020       0         0   False      94      0       2     0      3
# 172021       0         0   False      86      0       8     0     11
# 172022       0         0   False     302      0      34     0     35
# 172023       0         0   False     129      0      22     0     24
# 172024       0         0   False      87      0      20     0     21
# 172025       0         0   False     156      0      13     0     16
# 172026       0         0   False     121      0       4     0      6
# 172027       0         0   False     293      0      47     0     49
# 172028       0         0   False     748      0     137     0    138
# 172029       0         0   False    2000      0     435     0    461
# 172030       0         0   False     315      0      40     0     41
# 172031       0         0   False      42      0       7     0      8
# 172032       0         1   False    2607      2     408     0    410
# 172033       0         0   False     103      0       3     0      4
# 172034       0         0   False      56      0      11     0     13
# 172035       0         0   False      57      0       7     0      8
# 172036       0         0   False     207      0      21     0     22
# 172037       0         0   False     231      0      49     0     55
# 172038       0         0   False    2436      0     553     0    554
# 172039       0         0   False     221      0      25     0     30
# 172040       0         0   False    2650      0     455     0    456
# 172041       0         0   False      39      0       8     0      9
# 172042       0         0   False     131      0       8     0     10
# 172043       0         0   False     822      0     144     0    145
#
# [172044 rows x 8 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

label = 'istroll'
pre = labeled_train.columns.drop([label])
#pre = ['author','forumid']

model = RandomForestClassifier(n_estimators=10, n_jobs=6)

# %%
from sklearn import cross_validation

cv_value = 3

scores = cross_validation.cross_val_score(model, labeled_train[pre], labeled_train[label], cv=cv_value, scoring="roc_auc")
cv_result = scores.mean()

print(cv_result)
# Out:
# 0.575882998787
